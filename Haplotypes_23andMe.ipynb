# %% [markdown]
# ### Display results of haplogroup analysis

# %% [markdown]
# #### List of output files

# %%
ls
# Out:
# eye-color-and-23andme-data.ipynb*
# genome_Brian_Beck_haplogroups.png*
# genome_Brian_Beck_haplogroups.txt
# haplogroups.genome_Brian_Beck_v2_v3_Full_20190722220903.txt
# haplotype2.ipynb
# haplotype.ipynb
# Untitled.ipynb
# y.tree.aligned.hgSNP.2016.01.04.nwk
# y.tree.aligned.ycc.2016.01.04.nwk
# y.tree.hgSNP.2016.01.04.nwk
# y.tree.primary.aligned.ycc.2016.01.04.nwk
# y.tree.ycc.2016.01.04.nwk

# %% [markdown]
# ## Y Haplotype Results

# %%
Y_haplo = open("haplogroups.genome_Brian_Beck_v2_v3_Full_20190722220903.txt","r")

# %%
print(Y_haplo.read())
# Out:
# genome_Brian_Beck_v2_v3_Full_20190722220903 I-M253          I-M253          I1

# %%
y_tree = "y.tree.aligned.hgSNP.2016.01.04.nwk"

# %%
from ete3 import Tree

# %%
t = Tree(y_tree, format=1)

# %%
print(t)
# Out:
#                                        /-K-M147
#                                       |
#                                       |--K-P402
#                                       |
#                                       |--K-P261
#                                       |
#                                       |      /-P-P295*
#                                       |     |
#                                       |     |         /-R-M479*
#                                       |     |        |
#                                       |     |      /-|   /-R-L1069
#                                       |     |     |  |  |
#                                       |     |     |  |  |--R-L263
#                                       |     |     |   \-|
#                                       |     |     |     |      /-R-L723*
#                                       |     |     |     |   /-|
#                                       |     |     |     |  |  |   /-R-L725*
# ...

# %% [markdown]
# ## MT Haplotype Results

# %%
mt_haplo = open("genome_Brian_Beck_haplogroups.txt","r")

# %%
print(mt_haplo.read())
# Out:
# "SampleID"	"Range"	"Haplogroup"	"Rank"	"Quality"
# "genome_Brian_Beck"	"1-16569"	"T2b4+152"	"1"	"0.8798"

# %%
mt_hapgrp_img="genome_Brian_Beck_haplogroups.png"

# %%
from IPython.display import Image
Image(filename=mt_hapgrp_img)
